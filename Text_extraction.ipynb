# %%
pip install paddlepaddle==3.0.0b1 -i https://www.paddlepaddle.org.cn/packages/stable/cpu/
# Out:
# Looking in indexes: https://www.paddlepaddle.org.cn/packages/stable/cpu/
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.1; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\sachi\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.

# %%
pip install paddlepaddle-gpu==3.0.0b1 -i https://www.paddlepaddle.org.cn/packages/stable/cu123/
# Out:
# Looking in indexes: https://www.paddlepaddle.org.cn/packages/stable/cu123/
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.1; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\sachi\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.

# %%
# Install paddle OCR
! pip install paddleocr
# Out:
# ...
# Using legacy 'setup.py install' for fire, since package 'wheel' is not installed.
# ...
#     Running setup.py install for fire: started
#     Running setup.py install for fire: finished with status 'done'
# ...
# WARNING: You are using pip version 21.1.1; however, version 24.2 is available.
# You should consider upgrading via the 'c:\users\sachi\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
# Clone paddle OCR repo - get FONTS for visualization
! git clone https://github.com/PaddlePaddle/PaddleOCR
# Out:
# fatal: destination path 'PaddleOCR' already exists and is not an empty directory.

# %%
from paddleocr import PaddleOCR, draw_ocr # main OCR dependencies
from matplotlib import pyplot as plt # plot images
import cv2
import os # folder directory navigation
# Out:
# Error: Can not import paddle core while this file exists: c:\Users\sachi\AppData\Local\Programs\Python\Python38\lib\site-packages\paddle\base\libpaddle.pyd
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from paddleocr import PaddleOCR, draw_ocr # main OCR dependencies
#       2 from matplotlib import pyplot as plt # plot images
#       3 import cv2
#
# File c:\Users\sachi\AppData\Local\Programs\Python\Python38\lib\site-packages\paddleocr\__init__.py:14
#       1 # Copyright (c) 2020 PaddlePaddle Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from .paddleocr import *
#      15 import importlib.metadata as importlib_metadata
# ...

# %%
! pip install --force-reinstall paddlepaddle-gpu==2.0.0
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# ...
#    ---------------------------------------- 0.0/434.4 MB ? eta -:--:--
#    ---------------------------------------- 0.8/434.4 MB 5.6 MB/s eta 0:01:17
#    ---------------------------------------- 1.3/434.4 MB 3.7 MB/s eta 0:01:57
#    ---------------------------------------- 2.1/434.4 MB 4.2 MB/s eta 0:01:43
#    ---------------------------------------- 2.6/434.4 MB 3.2 MB/s eta 0:02:15
#    ---------------------------------------- 3.4/434.4 MB 3.4 MB/s eta 0:02:07
#    ---------------------------------------- 4.5/434.4 MB 3.7 MB/s eta 0:01:56
#    ---------------------------------------- 5.2/434.4 MB 3.8 MB/s eta 0:01:54
#    ---------------------------------------- 5.2/434.4 MB 3.8 MB/s eta 0:01:54
# ...

# %%
! pip install paddlepaddle-gpu==2.5.2 -i https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ---------------------------------------- 0.0/406.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/406.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/406.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/406.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/406.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/406.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/406.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/406.4 MB ? eta -:--:--
#      ---------------------------------------- 0.3/406.4 MB ? eta -:--:--
#      ---------------------------------------- 0.3/406.4 MB ? eta -:--:--
#      -------------------------------------- 0.5/406.4 MB 672.2 kB/s eta 0:10:04
#      -------------------------------------- 0.8/406.4 MB 860.9 kB/s eta 0:07:52
# ...

# %%
# !python -m pip uninstall paddlepaddle-gpu -y
# !python -m pip install paddlepaddle-gpu -i https://pypi.org/simple
# Out:
# Found existing installation: paddlepaddle-gpu 2.5.2
# Uninstalling paddlepaddle-gpu-2.5.2:
#   Successfully uninstalled paddlepaddle-gpu-2.5.2
# ...
#    ---------------------------------------- 0.0/477.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/477.4 MB ? eta -:--:--
#    ---------------------------------------- 1.0/477.4 MB 3.6 MB/s eta 0:02:13
#    ---------------------------------------- 1.0/477.4 MB 3.6 MB/s eta 0:02:13
#    ---------------------------------------- 1.6/477.4 MB 1.9 MB/s eta 0:04:10
#    ---------------------------------------- 2.1/477.4 MB 2.2 MB/s eta 0:03:35
#    ---------------------------------------- 2.6/477.4 MB 2.2 MB/s eta 0:03:40
#    ---------------------------------------- 3.4/477.4 MB 2.4 MB/s eta 0:03:18
#    ---------------------------------------- 4.2/477.4 MB 2.6 MB/s eta 0:02:59
#    ---------------------------------------- 5.0/477.4 MB 2.8 MB/s eta 0:02:49
# ...

# %%
# !python -m pip install paddlepaddle==2.6.2.post101 -i https://pypi.org/simple
# Out:
# ERROR: Could not find a version that satisfies the requirement paddlepaddle==2.6.2.post101 (from versions: 1.8.5, 2.2.1, 2.2.2, 2.3.0rc0, 2.3.0, 2.3.1, 2.3.2, 2.4.0rc0, 2.4.0, 2.4.1, 2.4.2, 2.5.0rc0, 2.5.0rc1, 2.5.0, 2.5.1, 2.5.2, 2.6.0, 2.6.1, 2.6.2, 3.0.0b0)
# ERROR: No matching distribution found for paddlepaddle==2.6.2.post101

# %%
from paddleocr import PaddleOCR, draw_ocr # main OCR dependencies
from matplotlib import pyplot as plt # plot images
import cv2
import os # folder directory navigation
# Out:
# Error: Can not import paddle core while this file exists: c:\Users\sachi\AppData\Local\Programs\Python\Python38\lib\site-packages\paddle\base\libpaddle.pyd
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from paddleocr import PaddleOCR, draw_ocr # main OCR dependencies
#       2 from matplotlib import pyplot as plt # plot images
#       3 import cv2
#
# File c:\Users\sachi\AppData\Local\Programs\Python\Python38\lib\site-packages\paddleocr\__init__.py:14
#       1 # Copyright (c) 2020 PaddlePaddle Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from .paddleocr import *
#      15 import importlib.metadata as importlib_metadata
# ...

# %%
# !python -m pip uninstall paddlepaddle-gpu -y
